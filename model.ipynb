# %%
import pandas as pd
from sklearn.linear_model import
linear regression
# Out:
#   File "/tmp/ipykernel_1620/178629479.py", line 2
#     from sklearn.linear_model import
#                                      ^
# SyntaxError: invalid syntax

# %%
import pandas as pd
from sklearn.linear_model import LinearRegression

# %%
data={"size":[1000,1200,1500,1800,20000],"price" :[200000,2500000,300000,3500000,400000]}
df=pd.DataFrame(data)
print (df)
# Out:
#     size    price
# 0   1000   200000
# 1   1200  2500000
# 2   1500   300000
# 3   1800  3500000
# 4  20000   400000

# %%
x=df[["size"]]
y=df["prize"]
model=LinearRegression()
model.fit(x,y)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'prize'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_1620/1170282673.py in <cell line: 0>()
#       1 x=df[["size"]]
# ----> 2 y=df["prize"]
# ...

# %%
x=df[["size"]]
y=df["price"]
model=LinearRegression()
model.fit(x,y)
# Out:
# LinearRegression()

# %%
prediction=model.predict([[1700]])
print("predicted price:",prediction)
# Out:
# predicted price: [1590939.97408953]
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
prediction =predict.model([[1200]])
print(prediction)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1620/2440775991.py in <cell line: 0>()
# ----> 1 prediction =predict.model([[1200]])
#       2 print(prediction)
#
# NameError: name 'predict' is not defined

# %%
prediction=model.predict([[1200]])
print("predicted price:",prediction)
# Out:
# predicted price: [1621960.55851447]
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
data={"size":[1000,1200,1300,1800,2000,2300,2800,3000
              ],

      "price":[20000,25000,30000,35000,40000,45000,50000,55000]
      }
      df=pd.DataFrame(data)
      print(df)
# Out:
#   File "/tmp/ipykernel_1620/2512439409.py", line 1
#     data={"size":[1000,1200,1300,1800,2000,2300,2800,3000
#                  ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
x=df[[size""]]
y=df["price"]
model=LinearRegression()
model.fir(x,y)
# Out:
#   File "/tmp/ipykernel_1620/1244486606.py", line 1
#     x=df[[size""]]
#               ^
# SyntaxError: invalid syntax

# %%
x=df[["size"]]
y=df["price"]
model=LinearRegression()
model.fir(x,y)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_1620/850473238.py in <cell line: 0>()
#       2 y=df["price"]
#       3 model=LinearRegression()
# ----> 4 model.fir(x,y)
#
# AttributeError: 'LinearRegression' object has no attribute 'fir'

# %%
x=df[[size""]]
y=df["price"]
model=LinearRegression()
model.fit(x,y)
# Out:
#   File "/tmp/ipykernel_1620/3506518182.py", line 1
#     x=df[[size""]]
#               ^
# SyntaxError: invalid syntax

# %%
x=df[["size"]]
y=df["price"]
model=LinearRegression()
model.fit(x,y)
# Out:
# LinearRegression()

# %%
prediction=model.predict([2800])
print(prediction)
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_1620/4122236009.py in <cell line: 0>()
# ----> 1 prediction=model.predict([2800])
#       2 print(prediction)
#
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_base.py in predict(self, X)
#     295             Returns predicted values.
#     296         """
# --> 297         return self._decision_function(X)
#     298
#     299     def _set_intercept(self, X_offset, y_offset, X_scale):
#
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_base.py in _decision_function(self, X)
#     274         check_is_fitted(self)
#     275
# ...

# %%
prediction=model.predict([[2800]])
print(prediction)
# Out:
# [1522694.68835469]
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
prediction=model.predict([[1000]])
print(prediction)
# Out:
# [1634368.79228444]
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
prediction=model.predict([[2500]])
print(prediction)
prediction=model.predict([[1800]])
print(prediction)
# Out:
# [1541307.03900964]
# [1584735.85720455]
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
data={"size":[1000,1200,1300,1800,2000,2300,2800,3000
              ],

      "price":[20000,25000,30000,35000,40000,45000,50000,55000]
      }
      df=pd.DataFrame(data)
      print(df)
# Out:
#   File "/tmp/ipykernel_1620/1797809550.py", line 6
#     df=pd.DataFrame(data)
#     ^
# IndentationError: unexpected indent

# %%
data={"size":[1000,1200,1300,1800,2000,2300,2800,3000
              ],

      "price":[20000,25000,30000,35000,40000,45000,50000,55000]
      }
df=pd.DataFrame(data)
print(df)
# Out:
#    size  price
# 0  1000  20000
# 1  1200  25000
# 2  1300  30000
# 3  1800  35000
# 4  2000  40000
# 5  2300  45000
# 6  2800  50000
# 7  3000  55000

# %%
x=df[["size"]]
y=df["price"]
model=LinearRegression()
model.fit(x,y)
# Out:
# LinearRegression()

# %%
prediction=model.predict([[2800]])
print(prediction)
prediction=model.predict([[2500]])
print(prediction)
# Out:
# [51799.61089494]
# [46896.88715953]
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
prediction=model.predict([[2000]])
print(prediction)
# Out:
# [38725.68093385]
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
prediction=model.predict([[3000]])
print(prediction)
# Out:
# [55068.09338521]
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
prediction=model.predict([[2800]])
print(prediction)
# Out:
# [51799.61089494]
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
prediction=model.predict([[2700]])
print(prediction)
# Out:
# [50165.36964981]
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
import joblib

# %%
joblib.dump(model,'linear_model.pkl')
# Out:
# ['linear_model.pkl']

# %%
from google.colab import files
files.download('linear_model.pkl')
